# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests
import urllib.request
import json

# %%
def html_to_df(url, clean_empty = False , attrs = {}, helper = None):
    
    html_content = requests.get(url).text
    soup = bs(html_content, "lxml")
    table = str(soup.find("table", attrs=attrs))
    df = pd.read_html(str(table))[0]
    
    if clean_empty :
        df = df.loc[:, ~df.isnull().all(axis = 0)]
        
    if helper:
        df = helper(df)   
    return df

# %%
url = "https://github.com/ayedaemon/RuckSack-Python/blob/master/log_analysis/access_log"
url1 = "https://github.com/ayedaemon/RuckSack-Python/blob/master/log_analysis/access_log2"
url2 = "https://github.com/robert456456456456/Web_server_log_parser/blob/master/devops.log"

# %%
def helper(df):
    df = pd.DataFrame(list(df[1].apply(lambda x: x.split())))
    df[3] = df[3].apply(lambda x: x.replace('[','') )
    df[4] = df[4].apply(lambda x: x.replace(']','') )
    df[5] = df.apply(lambda x : ' '.join([x[5],x[6]]).replace('"',''), axis = 1)
    df.drop([1,2,7,6],inplace=True,axis = 1)
    
    return df

# %%
def log_parser(str_):
    '''
    input:
        str_ : log string.
    output:
        return a dictionary which contain all element of log string.
    '''
    find = {}
    find['ip'] = str_.split()[0]
    find['RFC931'] = str_.split()[1]
    find['user'] = str_.split()[2]
    find['date'] = str_.split('[')[1].split()[0]
    find['gmt'] = str_.split('[')[1].split()[1].strip(']')
    try:
        if 'HTTP' in str_.split('"')[1].split()[-1]:
            find['action'] =  str_.split('"')[1].replace(str_.split('"')[1].split()[2],'').strip()
        else:
            find['action'] =  str_.split('"')[1].strip()
    except:
        find['action'] = '-'
    try:
        find['status'] = str_.split('"')[2].strip().split()[0]
    except:
        find['status'] = '-'
    try:
        find['size'] = str_.split('"')[2].strip().split()[1]
    except:
        find['size'] = '-'
    try:
        find['referrer'] = str_.strip().split('"')[3]
    except:
        find['referrer'] ='-'
    try:
        find['browser'] = str_.strip().split('"')[5]
    except:
        find['browser'] = '-'
        
    return find

# %%
def log_df(df,col_name ,columns = [] ):

    df = pd.DataFrame(list(df[col_name].apply(log_parser).values) )
    if len(df.columns) == len(columns):
        df.columns = columns
    return df

# %%
df1 = html_to_df(url,clean_empty=True)
df2 = html_to_df(url1,clean_empty=True)
df = pd.concat([df1, df2],ignore_index=True)

# %%
columns = ["User_ID","RFC931","User","date","gmt","action","status","size","referrer","browser"]
df=log_df(df,1,columns)

# %%
df.head()
# Out:
#       User_ID RFC931 User                  date    gmt  \
# 0   127.0.0.1      -    -  15/Jan/2021:08:54:07  +0000
# 1   127.0.0.1      -    -  15/Jan/2021:08:55:23  +0000
# 2   127.0.0.1      -    -  15/Jan/2021:09:01:38  +0000
# 3  172.17.0.1      -    -  15/Jan/2021:09:02:14  +0000
# 4  172.17.0.1      -    -  15/Jan/2021:09:02:15  +0000
#
#                                       action status   size  \
# 0                                      GET /    403   4006
# 1                   GET /cgi-bin/weakform.py    403    199
# 2                  GET /cgi-bin/weak_form.py    200     19
# 3                                      GET /    403   4288
# 4  GET /noindex/common/css/bootstrap.min.css    200  99548
#
#              referrer                                            browser
# 0                   -                                        curl/7.61.1
# 1                   -                                        curl/7.61.1
# 2                   -                                        curl/7.61.1
# 3                   -  Mozilla/5.0 (X11; Linux x86_64; rv:84.0) Gecko...
# 4  http://172.17.0.2/  Mozilla/5.0 (X11; Linux x86_64; rv:84.0) Gecko...

# %%
def XSS_finder(str_):
    flag = 0
    l1 = ['<','>','\\','`']
    l2 = ['/',')','(']
    for char in l1:
        aasci_encoding = '%'+hex(ord(char)).replace('0x','')
        if (char in str_) or (aasci_encoding in str_):
            flag = 1
            break
    if flag != 1:
        try:
            req_str = ''.join(str_.split('?')[1:])
            for char in l2:
                aasci_encoding = '%'+hex(ord(char)).replace('0x','')
                if (char in req_str) or (aasci_encoding in req_str):
                    flag = 1
                    break
        except:
            pass
    return bool(flag)

# %%
df['XSS_attack']=df['action'].apply(XSS_finder)

# %%
df
# Out:
#          User_ID RFC931 User                  date    gmt  \
# 0      127.0.0.1      -    -  15/Jan/2021:08:54:07  +0000
# 1      127.0.0.1      -    -  15/Jan/2021:08:55:23  +0000
# 2      127.0.0.1      -    -  15/Jan/2021:09:01:38  +0000
# 3     172.17.0.1      -    -  15/Jan/2021:09:02:14  +0000
# 4     172.17.0.1      -    -  15/Jan/2021:09:02:15  +0000
# ...          ...    ...  ...                   ...    ...
# 1795  172.17.0.1      -    -  16/Jan/2021:13:02:17  +0000
# 1796  172.17.0.1      -    -  16/Jan/2021:13:02:18  +0000
# 1797  172.17.0.1      -    -  16/Jan/2021:13:02:21  +0000
# 1798  172.17.0.1      -    -  16/Jan/2021:13:02:18  +0000
# 1799  172.17.0.1      -    -  16/Jan/2021:13:02:25  +0000
#
#                                           action status   size  \
# 0                                          GET /    403   4006
# 1                       GET /cgi-bin/weakform.py    403    199
# 2                      GET /cgi-bin/weak_form.py    200     19
# 3                                          GET /    403   4288
# 4      GET /noindex/common/css/bootstrap.min.css    200  99548
# ...                                          ...    ...    ...
# 1795     GET /cgi-bin/weak_form.py?TWKAXWKIA=KOC    200    323
# 1796  GET /cgi-bin/weak_form.py?TRHYOWPDR=HRBCPR    200    323
# 1797     GET /cgi-bin/weak_form.py?OQUED=RCPFFTG    200    323
# 1798      GET /cgi-bin/weak_form.py?JVCSMGFH=CCJ    200    323
# 1799    GET /cgi-bin/weak_form.py?OVNHVMONM=SRSQ    200    323
#
#                                                referrer  \
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                     -
# 4                                    http://172.17.0.2/
# ...                                                 ...
# 1795                   http://www.google.com/?q=SHJUUEA
# 1796  http://www.usatoday.com/search/results?q=UKLAE...
# 1797  http://www.usatoday.com/search/results?q=CRLDA...
# 1798                  http://www.google.com/?q=CJBONBRR
# 1799                     http://www.google.com/?q=WKOOK
#
#                                                 browser  XSS_attack
# 0                                           curl/7.61.1       False
# 1                                           curl/7.61.1       False
# 2                                           curl/7.61.1       False
# 3     Mozilla/5.0 (X11; Linux x86_64; rv:84.0) Gecko...       False
# 4     Mozilla/5.0 (X11; Linux x86_64; rv:84.0) Gecko...       False
# ...                                                 ...         ...
# 1795  Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US...       False
# 1796  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...       False
# 1797  Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US...       False
# 1798  Mozilla/5.0 (X11; U; Linux x86_64; en-US; rv:1...       False
# 1799  Mozilla/5.0 (Windows; U; Windows NT 6.1; en; r...       False
#
# [1800 rows x 11 columns]

# %%
df[df['XSS_attack']==True]
# Out:
#          User_ID RFC931 User                  date    gmt  \
# 754   172.17.0.1      -    -  15/Jan/2021:10:05:35  +0000
# 757   172.17.0.1      -    -  16/Jan/2021:05:29:02  +0000
# 758   172.17.0.1      -    -  16/Jan/2021:05:30:04  +0000
# 759   172.17.0.1      -    -  16/Jan/2021:05:30:42  +0000
# 760   172.17.0.1      -    -  16/Jan/2021:05:30:57  +0000
# 761   172.17.0.1      -    -  16/Jan/2021:05:31:04  +0000
# 762   172.17.0.1      -    -  16/Jan/2021:05:31:24  +0000
# 763   172.17.0.1      -    -  16/Jan/2021:05:31:28  +0000
# 764   172.17.0.1      -    -  16/Jan/2021:05:31:34  +0000
# 765   172.17.0.1      -    -  16/Jan/2021:05:32:02  +0000
# 766   172.17.0.1      -    -  16/Jan/2021:05:34:45  +0000
# 767   172.17.0.1      -    -  16/Jan/2021:05:35:56  +0000
# 768   172.17.0.1      -    -  16/Jan/2021:05:36:06  +0000
# 769   172.17.0.1      -    -  16/Jan/2021:05:36:15  +0000
# 770   172.17.0.1      -    -  16/Jan/2021:05:36:20  +0000
# 771   172.17.0.1      -    -  16/Jan/2021:05:36:32  +0000
# 772   172.17.0.1      -    -  16/Jan/2021:05:36:47  +0000
# 773   172.17.0.1      -    -  16/Jan/2021:05:37:21  +0000
# 774   172.17.0.1      -    -  16/Jan/2021:05:37:34  +0000
# 775   172.17.0.1      -    -  16/Jan/2021:05:37:45  +0000
# 1530  172.17.0.1      -    -  15/Jan/2021:10:05:35  +0000
# 1533  172.17.0.1      -    -  16/Jan/2021:05:29:02  +0000
# 1534  172.17.0.1      -    -  16/Jan/2021:05:30:04  +0000
# 1535  172.17.0.1      -    -  16/Jan/2021:05:30:42  +0000
# 1536  172.17.0.1      -    -  16/Jan/2021:05:30:57  +0000
# 1537  172.17.0.1      -    -  16/Jan/2021:05:31:04  +0000
# 1538  172.17.0.1      -    -  16/Jan/2021:05:31:24  +0000
# 1539  172.17.0.1      -    -  16/Jan/2021:05:31:28  +0000
# 1540  172.17.0.1      -    -  16/Jan/2021:05:31:34  +0000
# 1541  172.17.0.1      -    -  16/Jan/2021:05:32:02  +0000
# 1542  172.17.0.1      -    -  16/Jan/2021:05:34:45  +0000
# 1543  172.17.0.1      -    -  16/Jan/2021:05:35:56  +0000
# 1544  172.17.0.1      -    -  16/Jan/2021:05:36:06  +0000
# 1545  172.17.0.1      -    -  16/Jan/2021:05:36:15  +0000
# 1546  172.17.0.1      -    -  16/Jan/2021:05:36:20  +0000
# 1547  172.17.0.1      -    -  16/Jan/2021:05:36:32  +0000
# 1548  172.17.0.1      -    -  16/Jan/2021:05:36:47  +0000
# 1549  172.17.0.1      -    -  16/Jan/2021:05:37:21  +0000
# 1550  172.17.0.1      -    -  16/Jan/2021:05:37:34  +0000
# 1551  172.17.0.1      -    -  16/Jan/2021:05:37:45  +0000
# 1565  172.17.0.1      -    -  16/Jan/2021:12:40:33  +0000
# 1566  172.17.0.1      -    -  16/Jan/2021:12:40:52  +0000
# 1573  172.17.0.1      -    -  16/Jan/2021:12:46:56  +0000
# 1574  172.17.0.1      -    -  16/Jan/2021:12:47:26  +0000
# 1575  172.17.0.1      -    -  16/Jan/2021:12:47:49  +0000
# 1576  172.17.0.1      -    -  16/Jan/2021:12:48:13  +0000
# 1579  172.17.0.1      -    -  16/Jan/2021:12:53:50  +0000
# 1580  172.17.0.1      -    -  16/Jan/2021:12:55:16  +0000
#
#                                                  action status size  \
# 754   GET /cgi-bin/weak_form.py?fname=asdasd%3C%2Fp%...    200  355
# 757   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  328
# 758   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 759   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 760   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  341
# 761   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  357
# 762   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  357
# 763   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 764   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  357
# 765   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  357
# 766   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 767   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 768   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 769   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 770   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 771   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 772   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 773   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 774   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 775   GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  348
# 1530  GET /cgi-bin/weak_form.py?fname=asdasd%3C%2Fp%...    200  355
# 1533  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  328
# 1534  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 1535  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 1536  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  341
# 1537  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  357
# 1538  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  357
# 1539  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 1540  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  357
# 1541  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  357
# 1542  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 1543  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 1544  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 1545  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 1546  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 1547  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  340
# 1548  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 1549  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 1550  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    400  226
# 1551  GET /cgi-bin/weak_form.py?fname=abcd&lname=111...    200  348
# 1565  GET /cgi-bin/weak_form.py?fname=&lname=%3Cscri...    200  304
# 1566  GET /cgi-bin/weak_form.py?fname=sdfsdf&lname=%...    200  345
# 1573  GET /cgi-bin/weak_form.py?fname=abcd&lname=%3C...    200  348
# 1574  GET /cgi-bin/weak_form.py?fname=abcd&lname=%3C...    200  346
# 1575  GET /cgi-bin/weak_form.py?fname=abcd&lname=%3C...    200  357
# 1576  GET /cgi-bin/weak_form.py?fname=abcd&lname=%3C...    200  357
# 1579  GET /cgi-bin/weak_form.py?fname=abcd&lname=<sc...    200  342
# 1580  GET /cgi-bin/weak_form.py?fname=abcd&lname=<sc...    400  226
#
#                                                referrer  \
# 754   http://172.17.0.2/cgi-bin/weak_form.py?fname=s...
# 757                                                   -
# 758                                                   -
# 759                                                   -
# 760                                                   -
# 761                                                   -
# 762                                                   -
# 763                                                   -
# 764                                                   -
# 765                                                   -
# 766                                                   -
# 767                                                   -
# 768                                                   -
# 769                                                   -
# 770                                                   -
# 771                                                   -
# 772                                                   -
# 773                                                   -
# 774                                                   -
# 775                                                   -
# 1530  http://172.17.0.2/cgi-bin/weak_form.py?fname=s...
# 1533                                                  -
# 1534                                                  -
# 1535                                                  -
# 1536                                                  -
# 1537                                                  -
# 1538                                                  -
# 1539                                                  -
# 1540                                                  -
# 1541                                                  -
# 1542                                                  -
# 1543                                                  -
# 1544                                                  -
# 1545                                                  -
# 1546                                                  -
# 1547                                                  -
# 1548                                                  -
# 1549                                                  -
# 1550                                                  -
# 1551                                                  -
# 1565  http://172.17.0.2/cgi-bin/weak_form.py?fname=a...
# 1566  http://172.17.0.2/cgi-bin/weak_form.py?fname=&...
# 1573                                                  -
# 1574  http://172.17.0.2/cgi-bin/weak_form.py?fname=a...
# 1575                                                  -
# 1576                                                  -
# 1579                                                  -
# 1580                                                  -
#
#                                                 browser  XSS_attack
# 754   Mozilla/5.0 (X11; Linux x86_64; rv:84.0) Gecko...        True
# 757                                         curl/7.74.0        True
# 758                                         curl/7.74.0        True
# 759                                         curl/7.74.0        True
# 760                                         curl/7.74.0        True
# 761                                         curl/7.74.0        True
# 762                                         curl/7.74.0        True
# 763                                         curl/7.74.0        True
# 764                                         curl/7.74.0        True
# 765                                         curl/7.74.0        True
# 766                                                   -        True
# 767                                                   -        True
# 768                                                   -        True
# 769                                         curl/7.74.0        True
# 770                                                   -        True
# 771                                         curl/7.74.0        True
# 772                                                   -        True
# 773                                                   -        True
# 774                                                   -        True
# 775                                         curl/7.74.0        True
# 1530  Mozilla/5.0 (X11; Linux x86_64; rv:84.0) Gecko...        True
# 1533                                        curl/7.74.0        True
# 1534                                        curl/7.74.0        True
# 1535                                        curl/7.74.0        True
# 1536                                        curl/7.74.0        True
# 1537                                        curl/7.74.0        True
# 1538                                        curl/7.74.0        True
# 1539                                        curl/7.74.0        True
# 1540                                        curl/7.74.0        True
# 1541                                        curl/7.74.0        True
# 1542                                                  -        True
# 1543                                                  -        True
# 1544                                                  -        True
# 1545                                        curl/7.74.0        True
# 1546                                                  -        True
# 1547                                        curl/7.74.0        True
# 1548                                                  -        True
# 1549                                                  -        True
# 1550                                                  -        True
# 1551                                        curl/7.74.0        True
# 1565  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...        True
# 1566  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...        True
# 1573  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...        True
# 1574  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...        True
# 1575  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...        True
# 1576  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...        True
# 1579                                        curl/7.74.0        True
# 1580                                                  -        True

# %% [markdown]
# ## Hits Vs Time

# %%
import plotly.express as px
import plotly.graph_objs as go

# %%
df['date'] = pd.to_datetime(df['date'], format = '%d/%b/%Y:%H:%M:%S')

# %%
layout = go.Layout(height=600, width=1000,title='Hits Vs Time', xaxis=dict(title='Date',color='orange'),
                   yaxis=dict(title='Hits',color='blue'))

# %%
fig = px.line(x=df.date.unique(), y=df.date.value_counts(sort = False))
fig.layout=layout
fig.show()
# Out:
# <div>                            <div id="0c73b4ee-2995-4bf0-ba2e-b8e42a2ed469" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c73b4ee-2995-4bf0-ba2e-b8e42a2ed469")) {                    Plotly.newPlot(                        "0c73b4ee-2995-4bf0-ba2e-b8e42a2ed469",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["
"2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:44", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:44", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:46", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:46", "2021-01-15T09:33:45", "2021-01-15T09:33:46", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:45", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:45", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:45", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:47", "2021-01-15T09:33:47", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021-01-15T09:33:47", "2021-01-15T09:33:46", "2021-01-15T09:33:47", "2021-01-15T09:33:46", "2021-01-15T09:33:46", "2021 ...

# %% [markdown]
# ## Most and Least Visited Customers

# %%
def most_least_visited_customer(df,n=1,m=1):
    result = {}
    result['Most visited customer'] = list(df['User_ID'].value_counts().head(n).index)
    result['Least visited customer'] = list(df['User_ID'].value_counts().tail(m).index)
    return result

# %%
most_least_visited_customer(df)
# Out:
# {'Most visited customer': ['172.17.0.1'],
#  'Least visited customer': ['127.0.0.1']}

# %% [markdown]
# ## Most and Least Visited Webpages

# %%
def most_least_visited_webpages(df,n=1,m=1):
    result = {}
    result['Most visited webpage'] = list(df['action'].value_counts().head(n).index)
    result['Least visited webpage'] = list(df['action'].value_counts().tail(m).index)
    return result

# %%
most_least_visited_webpages(df)
# Out:
# {'Most visited webpage': ['GET /cgi-bin/weak_form.py'],
#  'Least visited webpage': ['GET /cgi-bin/weak_form.py?GCIDXEKGU=KDXKSEE']}

# %%
from tqdm.notebook import tqdm

def loc_dict_maker(unq_series):
    '''
    input:
        series: series of unique ip address.
    output:
        res: dict contain country code, lat, long.
    '''
    def ip_loc(x):
        '''
        input:
            x : ip address
        output:
            dictionary which contain country,latitude and longitude.
        '''
        res = {}
        url = "https://geolocation-db.com/jsonp/"+x
        with urllib.request.urlopen(url) as url:
            data = json.loads(url.read().decode().split("(")[1].strip(")"))
        res = {"country_code":data["country_code"], 'latitude':data['latitude'],'longitude':data['longitude']}
        try:
            res['alpha_3'] = pycountry.countries.get(alpha_2=country).alpha_3
        except:
            res['alpha_3'] = 'Not found'
        return res
    
    result = {}
    for ip in tqdm(unq_series):
        result[ip] = ip_loc(ip)
    return result

# %%
def add_location_data(df,column,keys):
    def loc_dict_maker(unq_series):
        '''
        input:
            series: series of unique ip address.
        output:
            res: dict contain country code, lat, long.
        '''
        def ip_loc(x):
            '''
            input:
                x : ip address
            output:
                dictionary which contain country,latitude and longitude.
            '''
            res = {}
            url = "https://geolocation-db.com/jsonp/"+x
            with urllib.request.urlopen(url) as url:
                data = json.loads(url.read().decode().split("(")[1].strip(")"))
            res = {"country_code":data["country_code"], 'latitude':data['latitude'],'longitude':data['longitude']}
            try:
                res['alpha_3'] = pycountry.countries.get(alpha_2=res["country_code"]).alpha_3
            except:
                res['alpha_3'] = 'Not found'
            return res

        result = {}
        for ip in tqdm(unq_series):
            result[ip] = ip_loc(ip)
        return result
    
    loc_dict = loc_dict_maker(df[column].unique())
    for key in keys:
        df[key] = df[column].apply(lambda x: loc_dict[x][key])
    return df

# %%
keys = ['country_code', 'latitude', 'longitude', 'alpha_3']
df = add_location_data(df,'User_ID',keys)
df.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
#       User_ID RFC931 User                date    gmt  \
# 0   127.0.0.1      -    - 2021-01-15 08:54:07  +0000
# 1   127.0.0.1      -    - 2021-01-15 08:55:23  +0000
# 2   127.0.0.1      -    - 2021-01-15 09:01:38  +0000
# 3  172.17.0.1      -    - 2021-01-15 09:02:14  +0000
# 4  172.17.0.1      -    - 2021-01-15 09:02:15  +0000
#
#                                       action status   size  \
# 0                                      GET /    403   4006
# 1                   GET /cgi-bin/weakform.py    403    199
# 2                  GET /cgi-bin/weak_form.py    200     19
# 3                                      GET /    403   4288
# 4  GET /noindex/common/css/bootstrap.min.css    200  99548
#
#              referrer                                            browser  \
# 0                   -                                        curl/7.61.1
# 1                   -                                        curl/7.61.1
# 2                   -                                        curl/7.61.1
# 3                   -  Mozilla/5.0 (X11; Linux x86_64; rv:84.0) Gecko...
# 4  http://172.17.0.2/  Mozilla/5.0 (X11; Linux x86_64; rv:84.0) Gecko...
#
#    XSS_attack country_code   latitude  longitude    alpha_3
# 0       False    Not found  Not found  Not found  Not found
# 1       False    Not found  Not found  Not found  Not found
# 2       False    Not found  Not found  Not found  Not found
# 3       False    Not found  Not found  Not found  Not found
# 4       False    Not found  Not found  Not found  Not found

# %%
def geo_plot(country_series,colorbar_title,title_text):
    fig = go.Figure(data=go.Choropleth(
    locations=country_series.value_counts().index, # Spatial coordinates
    z = country_series.value_counts().values, # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorscale = 'Reds',
    colorbar_title = "Millions USD",
     ))

    fig.update_layout(
    title_text = '2011 US Agriculture Exports by State',
    geo_scope='usa', # limite map scope to USA
    )

# %%
geo_plot(df[df['alpha_3']!= 'Not found']['alpha_3'],"No. of Users","User's Geolocation Data")

# %%
from plotly.offline import  iplot
def geo_plotting(country_series,colorbar_title,title):
    data = dict(
            type = 'choropleth',
            locations = country_series.value_counts().index,
            z = country_series.value_counts().values,
            colorbar = {'title' : colorbar_title},
          )
    layout = dict(
        title = title,
        geo = dict(
                showframe = False,
                projection = {'type':'natural earth'}
        )
    )
    choromap = go.Figure(data = [data],layout = layout)
    iplot(choromap)

# %%
geo_plotting(df[df['alpha_3']!= 'Not found']['alpha_3'],"No. of Users","User's Geolocation Data")
# Out:
# <div>                            <div id="fe12e83b-3824-4670-aa6c-cba38efc9728" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe12e83b-3824-4670-aa6c-cba38efc9728")) {                    Plotly.newPlot(                        "fe12e83b-3824-4670-aa6c-cba38efc9728",                        [{"colorbar": {"title": {"text": "No. of Users"}}, "locations": [], "type": "choropleth", "z": []}],                        {"geo": {"projection": {"type": "natural earth"}, "showframe": false}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidt ...
